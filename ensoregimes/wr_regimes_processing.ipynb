# %%
import glob
import os
from pathlib import Path
import numpy as np
import xarray as xr

# %%
# make list of era5 files
list_e5 = sorted(
    glob.glob(
        '/glade/derecho/scratch/molina/dailyz500_v052926/e5*.nc'
    )
)

# %%
len(list_e5)
# Out:
# 31471

# %%
ds = xr.open_mfdataset(list_e5)

# %%
ds
# Out:
# <xarray.Dataset> Size: 509MB
# Dimensions:  (time: 31471, lat: 40, lon: 101)
# Coordinates:
#     level    float64 8B 500.0
#   * time     (time) datetime64[ns] 252kB 1940-01-01 1940-01-02 ... 2026-02-28
#   * lat      (lat) float64 320B 21.0 22.5 24.0 25.5 27.0 ... 75.0 76.5 78.0 79.5
#   * lon      (lon) float64 808B 180.0 181.5 183.0 184.5 ... 327.0 328.5 330.0
# Data variables:
#     Z        (time, lat, lon) float32 509MB dask.array<chunksize=(1, 40, 101), meta=np.ndarray>

# %%
ds.to_netcdf('/glade/derecho/scratch/molina/dailyz500_v060126.nc')
